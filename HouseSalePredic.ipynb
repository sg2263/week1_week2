# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/drive/MyDrive/housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
x_train ,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2)
train_data=x_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10154    -117.90     33.88                28.0       2696.0           346.0
# 14234    -117.02     32.69                 7.0       6055.0          1004.0
# 13831    -117.23     34.51                 9.0       5756.0           807.0
# 17133    -122.15     37.47                39.0       1295.0           239.0
# 3280     -122.86     39.08                24.0       3127.0           674.0
# ...          ...       ...                 ...          ...             ...
# 1470     -121.98     37.95                16.0       2984.0           406.0
# 5694     -118.25     34.25                34.0       3150.0           518.0
# 5817     -118.24     34.13                45.0       1971.0           439.0
# 14208    -117.04     32.69                27.0       1790.0           356.0
# 16283    -121.29     37.93                24.0       1438.0           351.0
#
# ...

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity).astype(int)).drop(['ocean_proximity'],axis=1)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10154    -117.90     33.88                28.0       2696.0           346.0
# 14234    -117.02     32.69                 7.0       6055.0          1004.0
# 13831    -117.23     34.51                 9.0       5756.0           807.0
# 17133    -122.15     37.47                39.0       1295.0           239.0
# 3280     -122.86     39.08                24.0       3127.0           674.0
# ...          ...       ...                 ...          ...             ...
# 1470     -121.98     37.95                16.0       2984.0           406.0
# 5694     -118.25     34.25                34.0       3150.0           518.0
# 5817     -118.24     34.13                45.0       1971.0           439.0
# 14208    -117.04     32.69                27.0       1790.0           356.0
# 16283    -121.29     37.93                24.0       1438.0           351.0
#
# ...

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20623    -121.37     39.03                32.0       1158.0           244.0
# 16239    -121.30     37.97                52.0       2259.0           417.0
# 16495    -120.99     37.80                32.0       2564.0           513.0
# 8131     -118.12     33.83                45.0       1579.0           278.0
# 3994     -118.57     34.17                35.0       2072.0           318.0
# ...          ...       ...                 ...          ...             ...
# 18105    -122.04     37.30                25.0       3807.0           600.0
# 12116    -117.23     33.96                 5.0       9179.0          1361.0
# 13089    -121.35     38.55                22.0       2607.0           411.0
# 7046     -118.04     33.95                36.0       1976.0           368.0
# 14725    -117.01     32.80                17.0       1558.0           479.0
#
# ...

# %%
train_data.hist(figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>,
#         <Axes: title={'center': 'total_rooms'}>],
#        [<Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>],
#        [<Axes: title={'center': 'median_house_value'}>,
#         <Axes: title={'center': '<1H OCEAN'}>,
#         <Axes: title={'center': 'INLAND'}>,
#         <Axes: title={'center': 'ISLAND'}>],
#        [<Axes: title={'center': 'NEAR BAY'}>,
#         <Axes: title={'center': 'NEAR OCEAN'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(18,10))
sns.heatmap(train_data.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(x='latitude',y='longitude',data=train_data,hue="median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
x_train,y_train =train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
testdata=x_test.join(y_test)
testdata=testdata.join(pd.get_dummies(testdata.ocean_proximity).astype(int)).drop(['ocean_proximity'],axis=1)
x_test,y_test=testdata.drop(['median_house_value'],axis=1),testdata['median_house_value']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-ca6a5b82b4bd> in <cell line: 2>()
#       1 testdata=x_test.join(y_test)
# ----> 2 testdata=testdata.join(pd.get_dummies(testdata.ocean_proximity).astype(int)).drop(['ocean_proximity'],axis=1)
#       3 x_test,y_test=testdata.drop(['median_house_value'],axis=1),testdata['median_house_value']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'ocean_proximity'

# %%
reg.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-5c3e1a22801d> in <cell line: 1>()
# ----> 1 reg.score(x_test,y_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     846         from .metrics import r2_score
#     847
# --> 848         y_pred = self.predict(X)
#     849         return r2_score(y, y_pred, sample_weight=sample_weight)
#     850
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     304             Returns predicted values.
#     305         """
# --> 306         return self._decision_function(X)
#     307
#     308     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     283         check_is_fitted(self)
#     284
# ...

# %%
predictions=reg.predict(x_test)

# %%
plt.scatter(y_test,predictions)

# %%
sklearn.metrics.mean_absolute_error(y_test,predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-917dd5626c30> in <cell line: 1>()
# ----> 1 sklearn.metrics.mean_absolute_error(y_test,predictions)
#
# NameError: name 'sklearn' is not defined

# %%
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y_test, predictions)

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
