# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
data = pd.read_csv('/content/drive/MyDrive/creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
scaler = StandardScaler()
data[['Time', 'Amount']] = scaler.fit_transform(data[['Time', 'Amount']])

# %%
x=data.drop('Class',axis=1)
y=data['Class']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,stratify=y,test_size=0.25,random_state=42)

# %%
rf_model =RandomForestClassifier(n_estimators=70, random_state=42)
#cv_scores_rf = cross_val_score(rf_model, x_train, y_train, cv=5, scoring='accuracy')
#print("Cross-validation scores:", cv_scores_rf)
#print("Mean cross-validation score:", cv_scores_rf.mean())
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=70, random_state=42)

# %%
y_pred = rf_model.predict(x_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Test Accuracy: 0.9995365298727564
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.94      0.78      0.85       123
#
#     accuracy                           1.00     71202
#    macro avg       0.97      0.89      0.93     71202
# weighted avg       1.00      1.00      1.00     71202
#
# Confusion Matrix:
#  [[71073     6]
#  [   27    96]]

# %%
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,stratify=y_train,test_size=0.1,random_state=42)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

def create_model():
    model = Sequential()
    model.add(Dense(64, input_dim=x_train.shape[1], activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model


model = create_model()

history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=10, batch_size=32)

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.9976 - loss: 0.0167 - val_accuracy: 0.9990 - val_loss: 0.0048
# Epoch 2/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9994 - loss: 0.0030 - val_accuracy: 0.9992 - val_loss: 0.0039
# Epoch 3/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9992 - val_loss: 0.0036
# Epoch 4/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9992 - val_loss: 0.0041
# Epoch 5/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9991 - val_loss: 0.0039
# Epoch 6/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 0.9992 - val_loss: 0.0044
# Epoch 7/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 0.9992 - val_loss: 0.0038
# Epoch 8/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9992 - val_loss: 0.0042
# Epoch 9/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9992 - val_loss: 0.0043
# Epoch 10/10
# 6008/6008 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9992 - val_loss: 0.0041
# 2226/2226 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9994 - loss: 0.0027
# Test Accuracy: 0.9993680119514465
